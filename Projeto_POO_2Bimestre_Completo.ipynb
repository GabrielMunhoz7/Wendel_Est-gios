# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1

#Entrevistas Para Estágio


class EntrevistaEstagio_gab:
    def __init__(self, nome_candidato_gab, curso_gab, status_gab):
        self.nome_candidato_gab = nome_candidato_gab
        self.curso_gab = curso_gab
        self.status_gab = status_gab

    
    def exibir_gab(self):
        print(f"Nome do Candidato: {self.nome_candidato_gab}")
        print(f"Curso: {self.curso_gab}")
        print(f"Status da Entrevista: {self.status_gab}")
        print("-" * 30)

#teste
entrevista1_gab = EntrevistaEstagio_gab("Lucas Almeida", "Engenharia de Software", "Aprovado")
entrevista2_gab = EntrevistaEstagio_gab("Mariana Costa", "Administração", "Pendente")


entrevista1_gab.exibir_gab()
entrevista2_gab.exibir_gab()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2

class EntrevistaEstagio_gab:
    def __init__(self, nome_candidato_gab, curso_gab, status_gab):
        self.nome_candidato_gab = nome_candidato_gab
        self.curso_gab = curso_gab
        self.status_gab = status_gab

    def exibir_gab(self):
        print(f"Nome do Candidato: {self.nome_candidato_gab}")
        print(f"Curso: {self.curso_gab}")
        print(f"Status da Entrevista: {self.status_gab}")
        print("-" * 30)

    # Métodos de ação
    def alterar_status_gab(self, novo_status_gab):
        self.status_gab = novo_status_gab
        print(f"Status alterado para: {self.status_gab}")

    def atualizar_nome_gab(self, novo_nome_gab):
        self.nome_candidato_gab = novo_nome_gab
        print(f"Nome atualizado para: {self.nome_candidato_gab}")


class EntrevistaEstagioTecnico_gab(EntrevistaEstagio_gab):
    def __init__(self, nome_candidato_gab, curso_gab, status_gab, nivel_tecnico_gab):
        # Usando super() para herdar os atributos da classe principal
        super().__init__(nome_candidato_gab, curso_gab, status_gab)
        self.nivel_tecnico_gab = nivel_tecnico_gab

    # Novo método exclusivo na subclasse
    def exibir_nivel_tecnico_gab(self):
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")


entrevista1_gab = EntrevistaEstagio_gab("Lucas Almeida", "Engenharia de Software", "Aprovado")
entrevista2_gab = EntrevistaEstagio_gab("Mariana Costa", "Administração", "Pendente")
entrevista1_gab.exibir_gab()
entrevista2_gab.exibir_gab()


entrevista1_gab.alterar_status_gab("Reprovado")
entrevista2_gab.atualizar_nome_gab("Mariana Oliveira")
entrevista2_gab.exibir_gab()


entrevista_tecnica_gab = EntrevistaEstagioTecnico_gab("Carlos Souza", "Ciência da Computação", "Aprovado", "Sênior")
entrevista_tecnica_gab.exibir_gab()
entrevista_tecnica_gab.exibir_nivel_tecnico_gab()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3

class EntrevistaEstagio_gab:
    def __init__(self, nome_candidato_gab, curso_gab, status_gab):
        self.__nome_candidato_gab = nome_candidato_gab  # Atributo privado
        self.curso_gab = curso_gab
        self.status_gab = status_gab

    
    def get_nome_candidato_gab(self):
        return self.__nome_candidato_gab

    def set_nome_candidato_gab(self, novo_nome_gab):
        self.__nome_candidato_gab = novo_nome_gab

 
    def verificar_status_gab(self):
        if self.status_gab != "Aprovado":
            self.status_gab = "Reprovado"
        print(f"Status verificado: {self.status_gab}")

    def exibir_gab(self):
        print(f"Nome do Candidato: {self.get_nome_candidato_gab()}")
        print(f"Curso: {self.curso_gab}")
        print(f"Status da Entrevista: {self.status_gab}")
        print("-" * 30)

    
    def alterar_status_gab(self, novo_status_gab):
        self.status_gab = novo_status_gab
        print(f"Status alterado para: {self.status_gab}")

    def atualizar_nome_gab(self, novo_nome_gab):
        self.set_nome_candidato_gab(novo_nome_gab)
        print(f"Nome atualizado para: {self.get_nome_candidato_gab()}")


class EntrevistaEstagioTecnico_gab(EntrevistaEstagio_gab):
    def __init__(self, nome_candidato_gab, curso_gab, status_gab, nivel_tecnico_gab):
        super().__init__(nome_candidato_gab, curso_gab, status_gab)
        self.nivel_tecnico_gab = nivel_tecnico_gab

    def exibir_nivel_tecnico_gab(self):
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")

    def exibir_gab(self):
        super().exibir_gab()
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")
        print("-" * 30)


entrevista1_gab = EntrevistaEstagio_gab("Lucas Almeida", "Engenharia de Software", "Aprovado")
entrevista2_gab = EntrevistaEstagio_gab("Mariana Costa", "Administração", "Pendente")


entrevista1_gab.exibir_gab()
entrevista2_gab.exibir_gab()


entrevista1_gab.atualizar_nome_gab("Lucas Oliveira")
print(f"Novo nome após atualização: {entrevista1_gab.get_nome_candidato_gab()}")


entrevista2_gab.verificar_status_gab()
entrevista2_gab.exibir_gab()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4

import sqlite3


class EntrevistaEstagio_gab:
    def __init__(self, nome_candidato_gab, curso_gab, status_gab):
        self.__nome_candidato_gab = nome_candidato_gab  
        self.curso_gab = curso_gab
        self.status_gab = status_gab

    
    def get_nome_candidato_gab(self):
        return self.__nome_candidato_gab

    def set_nome_candidato_gab(self, novo_nome_gab):
        self.__nome_candidato_gab = novo_nome_gab

    
    def verificar_status_gab(self):
        if self.status_gab != "Aprovado":
            self.status_gab = "Reprovado"
        print(f"Status verificado: {self.status_gab}")

    def exibir_gab(self):
        print(f"Nome do Candidato: {self.get_nome_candidato_gab()}")
        print(f"Curso: {self.curso_gab}")
        print(f"Status da Entrevista: {self.status_gab}")
        print("-" * 30)

    
    def alterar_status_gab(self, novo_status_gab):
        self.status_gab = novo_status_gab
        print(f"Status alterado para: {self.status_gab}")

    def atualizar_nome_gab(self, novo_nome_gab):
        self.set_nome_candidato_gab(novo_nome_gab)
        print(f"Nome atualizado para: {self.get_nome_candidato_gab()}")

    s
    def inserir_no_banco(self, conn):
        cursor = conn.cursor()
        cursor.execute("INSERT INTO entrevistas (nome, curso, status) VALUES (?, ?, ?)", 
                       (self.get_nome_candidato_gab(), self.curso_gab, self.status_gab))
        conn.commit()

    
    @staticmethod
    def consultar_banco(conn):
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM entrevistas")
        entrevistas = cursor.fetchall()
        for entrevista in entrevistas:
            print(f"ID: {entrevista[0]}, Nome: {entrevista[1]}, Curso: {entrevista[2]}, Status: {entrevista[3]}")
        print("-" * 30)

    
    @staticmethod
    def excluir_do_banco(conn, id_entrevista):
        cursor = conn.cursor()
        cursor.execute("DELETE FROM entrevistas WHERE id = ?", (id_entrevista,))
        conn.commit()


class EntrevistaEstagioTecnico_gab(EntrevistaEstagio_gab):
    def __init__(self, nome_candidato_gab, curso_gab, status_gab, nivel_tecnico_gab):
        super().__init__(nome_candidato_gab, curso_gab, status_gab)
        self.nivel_tecnico_gab = nivel_tecnico_gab

    def exibir_nivel_tecnico_gab(self):
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")

   
    def exibir_gab(self):
        super().exibir_gab()
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")
        print("-" * 30)


def criar_banco():
    conn = sqlite3.connect('entrevistas.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS entrevistas (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        nome TEXT,
        curso TEXT,
        status TEXT
    )''')
    conn.commit()
    return conn


conn = criar_banco()


entrevista1_gab = EntrevistaEstagio_gab("Lucas Almeida", "Engenharia de Software", "Aprovado")
entrevista2_gab = EntrevistaEstagioTecnico_gab("Carlos Souza", "Ciência da Computação", "Pendente", "Pleno")


entrevista1_gab.inserir_no_banco(conn)
entrevista2_gab.inserir_no_banco(conn)


print("Consultando entrevistas no banco de dados:")
EntrevistaEstagio_gab.consultar_banco(conn)


print("Excluindo entrevista com ID 1...")
EntrevistaEstagio_gab.excluir_do_banco(conn, 1)


print("Consultando entrevistas após exclusão:")
EntrevistaEstagio_gab.consultar_banco(conn)


conn.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5

import sqlite3

# Classe Principal - EntrevistaEstagio_gab
class EntrevistaEstagio_gab:
    def __init__(self, nome_candidato_gab, curso_gab, status_gab):
        # Atributos privados e públicos
        self.__nome_candidato_gab = nome_candidato_gab  # Atributo privado
        self.curso_gab = curso_gab
        self.status_gab = status_gab

    # Métodos get e set para o atributo privado __nome_candidato_gab
    def get_nome_candidato_gab(self):
        return self.__nome_candidato_gab

    def set_nome_candidato_gab(self, novo_nome_gab):
        self.__nome_candidato_gab = novo_nome_gab

    # Método para verificar o status do candidato, alterando para "Reprovado" se não for "Aprovado"
    def verificar_status_gab(self):
        if self.status_gab != "Aprovado":
            self.status_gab = "Reprovado"
        print(f"Status verificado: {self.status_gab}")

    # Exibir informações sobre o candidato
    def exibir_gab(self):
        print(f"Nome do Candidato: {self.get_nome_candidato_gab()}")
        print(f"Curso: {self.curso_gab}")
        print(f"Status da Entrevista: {self.status_gab}")
        print("-" * 30)

    # Método para alterar o status da entrevista
    def alterar_status_gab(self, novo_status_gab):
        self.status_gab = novo_status_gab
        print(f"Status alterado para: {self.status_gab}")

    # Método para atualizar o nome do candidato usando set
    def atualizar_nome_gab(self, novo_nome_gab):
        self.set_nome_candidato_gab(novo_nome_gab)
        print(f"Nome atualizado para: {self.get_nome_candidato_gab()}")

    # Método para inserir dados no banco de dados
    def inserir_no_banco(self, conn):
        cursor = conn.cursor()
        cursor.execute("INSERT INTO entrevistas (nome, curso, status) VALUES (?, ?, ?)", 
                       (self.get_nome_candidato_gab(), self.curso_gab, self.status_gab))
        conn.commit()

    # Método para consultar dados do banco de dados
    @staticmethod
    def consultar_banco(conn):
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM entrevistas")
        entrevistas = cursor.fetchall()
        for entrevista in entrevistas:
            print(f"ID: {entrevista[0]}, Nome: {entrevista[1]}, Curso: {entrevista[2]}, Status: {entrevista[3]}")
        print("-" * 30)

    # Método para deletar dados do banco de dados com base no ID
    @staticmethod
    def excluir_do_banco(conn, id_entrevista):
        cursor = conn.cursor()
        cursor.execute("DELETE FROM entrevistas WHERE id = ?", (id_entrevista,))
        conn.commit()

# Subclasse de EntrevistaEstagio_gab com polimorfismo
class EntrevistaEstagioTecnico_gab(EntrevistaEstagio_gab):
    def __init__(self, nome_candidato_gab, curso_gab, status_gab, nivel_tecnico_gab):
        super().__init__(nome_candidato_gab, curso_gab, status_gab)
        self.nivel_tecnico_gab = nivel_tecnico_gab

    # Exibir o nível técnico do candidato
    def exibir_nivel_tecnico_gab(self):
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")

    # Sobrescrevendo o método exibir_gab da classe principal para adicionar o nível técnico
    def exibir_gab(self):
        super().exibir_gab()  # Chama o método exibir_gab da classe base
        print(f"Nível Técnico: {self.nivel_tecnico_gab}")
        print("-" * 30)

# Função para criar o banco de dados SQLite
def criar_banco():
    # Conectando ao banco de dados SQLite (ou criando caso não exista)
    conn = sqlite3.connect('entrevistas.db')
    cursor = conn.cursor()

    # Criando a tabela de entrevistas, caso não exista
    cursor.execute('''CREATE TABLE IF NOT EXISTS entrevistas (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        nome TEXT,
        curso TEXT,
        status TEXT
    )''')
    conn.commit()
    return conn

# Função para testar todas as funcionalidades
def testar_funcionalidades():
    # Criar a conexão com o banco de dados
    conn = criar_banco()

    # Criando objetos de entrevistas
    entrevista1_gab = EntrevistaEstagio_gab("Lucas Almeida", "Engenharia de Software", "Aprovado")
    entrevista2_gab = EntrevistaEstagioTecnico_gab("Carlos Souza", "Ciência da Computação", "Pendente", "Pleno")

    # Inserindo dados no banco de dados
    entrevista1_gab.inserir_no_banco(conn)
    entrevista2_gab.inserir_no_banco(conn)

    # Consultando dados do banco
    print("Consultando entrevistas no banco de dados:")
    EntrevistaEstagio_gab.consultar_banco(conn)

    # Excluindo uma entrevista (usando o ID)
    print("Excluindo entrevista com ID 1...")
    EntrevistaEstagio_gab.excluir_do_banco(conn, 1)

    # Consultando novamente após a exclusão
    print("Consultando entrevistas após exclusão:")
    EntrevistaEstagio_gab.consultar_banco(conn)

    # Alterando status de uma entrevista
    entrevista2_gab.alterar_status_gab("Aprovado")
    entrevista2_gab.exibir_gab()

    # Testando o método de verificação de status
    entrevista2_gab.verificar_status_gab()
    
    # Testando a sobrescrição do método exibir_gab
    entrevista2_gab.exibir_gab()

    # Fechando a conexão com o banco de dados
    conn.close()

# Chama a função de teste para testar todas as funcionalidades
testar_funcionalidades()
